# %%
from lume_cheetah import LUMECheetahModel
from simulator import CheetahSimulator

# %%
#load the model variables into memory
from utils.loading import  variables_from_yaml
variables_from_yaml("model_configs/model_config_nc_injector_DL1.yaml")
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[3], line 3
#       1 #load the model variables into memory
#       2 from utils.loading import  variables_from_yaml
# ----> 3 variables_from_yaml("model_configs/model_config_nc_injector_DL1.yaml")
#
# File ~/fel_sandbox/LUMECheetah/utils/loading.py:152, in variables_from_yaml(yaml_obj)
#     150     yaml_str = yaml_obj
#     151 config = deserialize_variables(yaml.safe_load(yaml_str))
# --> 152 return variables_from_dict(config)
#
# File ~/fel_sandbox/LUMECheetah/utils/loading.py:127, in variables_from_dict(config)
#     125 variable_class = get_variable(var["variable_class"])
#     126 if key == "input_variables":
# --> 127     input_variables.append(variable_class(**var))
#     128 elif key == "output_variables":
#     129     output_variables.append(variable_class(**var))
#
# ...

# %%
# need to fix config file first, get it to load into memory
# pass supported_variables into LUMECheetahModel. and test setting method.
